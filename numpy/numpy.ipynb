# %%
#python list

numbers = [1,2,3,4]

result=[]

for x in numbers:
     result.append(x*2)
print(result)
# Out:
# [2, 4, 6, 8]

# %%
import numpy as np

arr = np.array(numbers)

print(arr*2)
# Out:
# [2 4 6 8]

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])

print(arr * 2)
# Out:
# [2 4 6 8]
